# %% [markdown]
# # Big O & Asymptotic Annotation
#
# > Relacionado a escalabilidade - Como o algoritmo escala de acordo com o tamanho do input(entrada).
# > Conseguimos comparar a performance de um algoritmo com outro utilizando a notação Big O.
# >
